# %%
i=1
j=1

# %%
for i in range(1,10):
    for j in range(1,10):
        s=1*j
        print(i,'x',j,'=',s)
    print()
# Out:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
#
# 2 x 1 = 1
# 2 x 2 = 2
# 2 x 3 = 3
# 2 x 4 = 4
# 2 x 5 = 5
# 2 x 6 = 6
# 2 x 7 = 7
# 2 x 8 = 8
# 2 x 9 = 9
#
# 3 x 1 = 1
# 3 x 2 = 2
# 3 x 3 = 3
# 3 x 4 = 4
# 3 x 5 = 5
# 3 x 6 = 6
# 3 x 7 = 7
# 3 x 8 = 8
# 3 x 9 = 9
#
# 4 x 1 = 1
# 4 x 2 = 2
# 4 x 3 = 3
# 4 x 4 = 4
# 4 x 5 = 5
# 4 x 6 = 6
# 4 x 7 = 7
# 4 x 8 = 8
# 4 x 9 = 9
#
# 5 x 1 = 1
# 5 x 2 = 2
# 5 x 3 = 3
# 5 x 4 = 4
# 5 x 5 = 5
# 5 x 6 = 6
# 5 x 7 = 7
# 5 x 8 = 8
# 5 x 9 = 9
#
# 6 x 1 = 1
# 6 x 2 = 2
# 6 x 3 = 3
# 6 x 4 = 4
# 6 x 5 = 5
# 6 x 6 = 6
# 6 x 7 = 7
# 6 x 8 = 8
# 6 x 9 = 9
#
# 7 x 1 = 1
# 7 x 2 = 2
# 7 x 3 = 3
# 7 x 4 = 4
# 7 x 5 = 5
# 7 x 6 = 6
# 7 x 7 = 7
# 7 x 8 = 8
# 7 x 9 = 9
#
# 8 x 1 = 1
# 8 x 2 = 2
# 8 x 3 = 3
# 8 x 4 = 4
# 8 x 5 = 5
# 8 x 6 = 6
# 8 x 7 = 7
# 8 x 8 = 8
# 8 x 9 = 9
#
# 9 x 1 = 1
# 9 x 2 = 2
# 9 x 3 = 3
# 9 x 4 = 4
# 9 x 5 = 5
# 9 x 6 = 6
# 9 x 7 = 7
# 9 x 8 = 8
# 9 x 9 = 9
